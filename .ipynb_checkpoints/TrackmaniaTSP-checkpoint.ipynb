# %% [markdown]
# # Trackmania Project : Optimizing checkpoints order on E02

# %% [markdown]
# ## Le projet :
# _______
#
# Le but de notre projet était de répondre à la problématique : Quelle est la meilleure façon de parcourir les différents checkpoints d'un circuit pour le terminer le plusrapidement possible ?
#
# Nous nous intéressons ici au cas particulier du circuit E02 du jeu vidéo TrackMania Nations Forever
#
# ![alt text](hqdefault.jpg)
#
# ___
#
# Nous nous sommes intéressés à ce circuit en particulier puisque c'est le circuit possèdant les plus de voies alternatives et de checkpoints à valider de la série de jeu TrackMania.
#
# Pour le petit historique, plusieurs millions de joueurs essayent tant bien que mal d'inscrire leur temps dans le haut du classement de chaque circuit. De 2008 à 2019, le record de E02 n'a cessé de baisser jusqu'à atteindre les 3:48.59, record réalisé par Wirtual.
#
# Le niveau de jeu des joueurs experts étant assez homogène, les places dans le top 100 se jouent à quelques centièmes de secondes.
#
# Il y a de cela 10 mois, Wirtual bat son propre record du monde de plus de 14 secondes.
# Pour réaliser cet exploit, Wirtual a utilisé de noumbreux "cuts" (passage d'une partie à une autre du circuit, non prévu par les créateurs). Tous ces cuts étaient déjà largement connus parmis les meilleurs joueurs, mais il était assez compliqué de savoir si ils pouvaient ou non faire gagner du temps, et si oui dans quel ordre les prendre.
# Le nombre de cuts possibles étant trop élevé pour une recherche exhaustive, sans compter sur la difficulté de réalisation de certains d'entre eux, Wirtual décida de chronométrer tous les passages possibles et d'exprimer ce problème comme un problème de voyageur de commerce (Traveling Salesman Problem).
#
# > Le problème du voyageur de commerce, ou problème du commis voyageur, est un problème d'optimisation qui, étant donné une liste de villes, et des distances entre toutes les paires de villes, détermine un plus court chemin qui visite chaque ville une et une seule fois et qui termine dans la ville de départ.
#
# Ici, les villes constitueront les checkpoints et la distance sera définie comme le temps nécessaire pour aller d'un checkpoint à un autre. Nous pouvons noter qu'il s'agit d'un problème dit TSP asymétrique puisque il n'est pas toujours possible de faire la jonction entre deux checkpoints dans les deux sens.
#
# Notre objectif dans ce projet est donc d'essayer de réaliser la même étude, en s'appuyant sur différentes méthodes de résolution, à savoir : l'algorithme de Little (Branch and Bound) et une modélisation du problème sous forme de Programmation Linéaire en Nombres Entiers

# %% [markdown]
# ## L'avancement du projet
# ____
#
# $$Rendu\ intermédiare$$
# Nous avons décider d'organiser notre travail dans l'odre suivant :
# * **Obternir un version fonctionnelle avec l'algorithe de Little, sur l'exemple du polycopié**
# * **Réussir à importer nos données depuis un fichier csv pour faciliter l'importation des temps**
# * **Tester l'algorithme de Little sur un circuit de notre cru (Avec peu de checkpoints)**
# * **Obtenir une version fonctionnelle de la version PLNE (Miller-Tucker-Zemlin)**
# * Obtenir une version fonctionnelle de la version PLNE (Dantzig-Fulkerson-Johnson)
# * Récupérer les données de temps du circuit E02
# * Importer les données de temps du circuit E02
# * Comparer les temps d'éxécution et les résulats de nos différentes approches sur les données de E02
# * Comparaison générale des 3 approches
# * Optionnel : Test des algorithmes génétiques / fourmillière de résolution de TSP, même si la taille de notre problème ne s'y prête pas vraiment
# * Tentative de record du monde par Hugo
#
# Comme vous pourrez être amené à le voir ci-dessous, une majorité des étapes les plus difficiles a déja été réalisée. L'algorithme de Little et la formulation PLNE (M-T-Z) semblent parfaitement fonctionner sur les différents exemples que nous leur avons passés.
#
# Nous avons choisi l'approche "dictionnaire" plutôt que l'approche matricielle pour la description puLp du problème, puisque contrairement à un problème TSP plus "classique", une majorité des trajets ne peut pas être réalisé dans un temps raisonnable. Une modélisation matricielle aurait défini beaucoup de contraintes inutiles et complexifié notre problème.
#
# Finalement, nous allons passer les prochains jours à nous atteler à la modélisation (D-F-J) du modèle PLNE et à la comparaison de nos différentes méthodes.
#
# Le fait que la majorité des trajets ne soit pas possible semble "diminuer la complexité" de l'algorithme de Little et nous avons été agréablement surpris du peu de branches explorées pour la résolution de notre exemple jouet à 8 checkpoints. Alors que l'algorithme est censé exploser en complexité bien avant la marque des 26 villes, nous sommes pressés de voir si l'algorithme parviendra tout de même à trouver le meilleur chemin
#
# Comme écrit dans la liste des tâches, nous essaierons également d'effectuer quelques tests d'algorithmes de résolution génétiques, bien que notre problème soit de taille assez faible pour être résolu de manière exacte en un temps convenable
#
# ___
#
# $$Rendu\ final$$
# Voici l'avancement des tâches depuis le dernier rendu :
# * **Obternir un version fonctionnelle avec l'algorithe de Little, sur l'exemple du polycopié**
# * **Réussir à importer nos données depuis un fichier csv pour faciliter l'importation des temps**
# * **Tester l'algorithme de Little sur un circuit de notre cru (Avec peu de checkpoints)**
# * **Obtenir une version fonctionnelle de la version PLNE (Miller-Tucker-Zemlin)**
# * **Obtenir une version fonctionnelle de la version PLNE (Dantzig-Fulkerson-Johnson)**
# * **Récupérer les données de temps du circuit E02**
# * **Importer les données de temps du circuit E02**
# * **Comparer les temps d'éxécution et les résulats de nos différentes approches sur les données de E02**
# * **Comparaison générale des 3 approches**
# * Optionnel : Test des algorithmes génétiques / fourmillière de résolution de TSP, même si la taille de notre problème ne s'y prête pas vraiment
# * Tentative de record du monde par Hugo
#
# Depuis le rendu intermédiaire, nous avons travaillé sur la résolution de problème initial, à savoir le speedrun de E02, et corrigé queqlues algorithmes.
# Dans un premier temps nous avons réussi à récupérer tous les temps chronométrés du circuit en question. Le fichier étant au format excel et à la configuration très peu arrangeante, nous avons modifié le tout afin de le rendre exploitable pour nos algorithmes de résolution.
# Une fois les temps chargés en format matrice, nous avons pu nous rendre compte que notre Algorithme de Little n'était pas correct, de même que notre fonction d'affichage du résultat. Les deux problèmes étaient liés au calcul de la profondeur du chemin emprunté, faussés par le fait qu'un non-choix augmentait également la profondeur de l'arbre.
# La fonction getRealNodeDepth nous a permis de résoudre ces deux problèmes

# %% [markdown]
# # Branch and Bound Algorithm (Little)

# %% [markdown]
# ## > Dependencies

# %%
import time
import numpy as np
from treelib import Node, Tree #You can pip install treelib
from itertools import chain, combinations
import pandas as pd

# %% [markdown]
# ## > Defining functions

# %%
def matrixReduction(matrix):
    red_matrix = np.copy(matrix)
    n = red_matrix.shape[0]
    evaluation = 0
    
    for j in range(n):
        if(np.min(red_matrix[:,j])!= np.inf):
            evaluation += np.min(red_matrix[:,j])
            red_matrix[:,j] = red_matrix[:,j] - np.min(red_matrix[:,j])

    for i in range(n):
        if(np.min(red_matrix[i,:])!= np.inf):
            evaluation += np.min(red_matrix[i,:])
            red_matrix[i,:] = red_matrix[i,:] - np.min(red_matrix[i,:])
            
    return (red_matrix, evaluation)

# %%
def calculerRegret(i,j, matrix):
    mat_cout = np.copy(matrix)
    mat_cout[i,j] = np.inf
    cout = np.min(mat_cout[i,:])
    cout += np.min(mat_cout[:,j])
    return cout

# %%
def visitNode(n, matrix, e, unavailable,parent_id):
    
    global maxi
    global tree
    global node_id
    global nodes
    root = nodes[0]
    s = tree.get_node(parent_id).tag #gets the name of the parent node
    
    if(e<=maxi):
        
        if(n != 0 or s[:len(root)] == root): #check if the parent node is the root
            
            availableNodes = np.where(matrix[n,:]!=np.inf)[0]
            regrets = {}
            change = False
            
            for node in availableNodes:
                if(node!=unavailable):
                    regrets[node] = calculerRegret(n,node, matrix)
                    change = True
            
            if(change):
                
                
                maxRegret = int(max(regrets, key=regrets.get)) #Retourne la clé de la valeur max
                
                new_matrix = np.copy(matrix)
                new_matrix[n,:] = np.inf
                new_matrix[:,maxRegret] = np.inf
                new_matrix[maxRegret,n] = np.inf
                
                new_matrix_2 = np.copy(matrix)
                new_matrix_2[n,maxRegret] = np.inf
                
                (new_matrix, coutevaluation) = matrixReduction(new_matrix)
                (new_matrix_2, coutevaluation2) = matrixReduction(new_matrix_2)
                
                localid = int(node_id)
                #________V__________
                e_v = e + coutevaluation
                
                node_id += 1
                tree.create_node(nodes[maxRegret]+' '+str(e_v), node_id, parent=localid, data=e_v)
                if(node_id<10000000):               
                    visitNode(maxRegret,new_matrix,e_v,None,localid)
                
                #______Vbarre_______
                e_v_barre = e + regrets[maxRegret]
                node_id += 1
                tree.create_node(nodes[n]+'!'+nodes[maxRegret]+' '+str(e_v_barre), node_id, parent=localid, data=e_v_barre)
                if(node_id<10000000):          
                    visitNode(n,new_matrix_2, e_v_barre,None,localid)

        else:
            if (getRealNodeDepth(tree,parent_id)>26):
                maxi = min(maxi,e)
                print(parent_id)

# %%
#Fonction appelant l'algorithe de résolution de Little
def Little(matrix, racine):
    
    global maxi
    global tree
    global node_id

    localid = int(node_id)
    
    n=racine
    (matrix, e) = matrixReduction(matrix)
    unavailable = None #Réduire la matrice et calculer E
    
    tree.create_node(nodes[n], node_id)
    
    visitNode(n,matrix, e,None, localid) #Visiter la racine

# %%
#Affichage du meilleur chemin
def Path(tree):
    
    global nodes
    
    minimum = np.inf
    min_node = None
    for node in tree.all_nodes_itr():
        if(node.tag[:len(nodes[0])]==nodes[0] and node.data != None and node.tag[len(nodes[0])]!="!" and node.tag[len(nodes[0])+1] != "!"):
            if(node.data <= minimum and getRealNodeDepth(tree,node) > len(nodes)):
                minimum = node.data
                min_node = node


    depth = tree.depth(min_node)
    node = min_node
    path = [min_node.tag.split(' ')[0]]
    #print('min node :', min_node)
    
    for i in range(depth):
        node = tree.parent(node.identifier)
        #print(node)
        if("!" not in node.tag):
            path.append(node.tag.split(' ')[0])
    path.reverse()
    
    print('Found optimal tour!')
    print(' -> '.join(path))
    print('Total cost : {}s'.format(min_node.data))
    
    #return (path, min_node.data)

# %%
def getRealNodeDepth(tree,node):
    if(type(node)==int):
        node = tree.get_node(node)
    depth = tree.depth(node)
    compteur = 1
    for i in range(depth):
        node = tree.parent(node.identifier)
        if("!" not in node.tag):
            compteur +=1
    return compteur

# %% [markdown]
# ## > Testing

# %% [markdown]
# ### >> Textbook example
#
# Cet exemple est directement tiré de l'énoncé du projet. Il nous a servi de premier test pour l'algorithme de Little et nous a permis de vérifer que ce dernier continuait de bien fonctionner au fur et à mesure que nous corrigions d'autres problèmes.
#
# Quoi que toujours utile, ce TSP ne correspond pas exactement à la forme de notre problème : Les distances sont symétriques et tous les sommets sont accessibles depuis n'importe lequel de ses voisins.
#
# **Meilleur chemin : Bordeaux -> Lyon -> Paris -> Nantes -> Bordeaux**
# ___
#
# <img src="cities.png" alt="drawing" width="600"/>

# %%
maxi = np.inf
costs = np.array([[maxi,780,320,580],
                 [780,maxi,700,460],
                 [320,700,maxi,380],
                  [580,460,380,maxi]])
nodes = ['Bordeaux','Lyon','Nantes','Paris']

# %%
tree = Tree()
node_id = 1

# %time Little(costs,0)
# Out:
# Wall time: 6 ms

# %%
Path(tree)
# Out:
# Found optimal tour!
# Bordeaux -> Lyon -> Paris -> Nantes -> Bordeaux
# Total cost : 1940.0s

# %% [markdown]
# ### >> Toy example
#
# Ce deuxième exemple dit "exemple jouet" nous sert également d'exemple de test afin de tester le bon fonctionnement de nos algorithmes sans se lancer directement dans des problèmes lourds en calcul.
# L'idée générale était de modéliser un circuit possible, où une majorité des sommets serait inaccessibles depuis un sommet donné.
#
# De plus, la résolution d'un problème TSP consiste à trouver une boucle de plus faible coût passant par tous les sommets. Notre circuit de voiture n'étant pas un circuit bouclant (le checkpoint final est différent du checkpoint de départ), nous avons décider de modéliser le problème en laissant un unique arc de retour jusqu'au checkpoint de départ, de coût nul, et prenant son origine dans le checkpoint d'arrivée.
#
# **Meilleur chemin : 1 -> 2 -> 3 -> 5 -> 4 -> 7 -> 6 -> 8**
# ___
#
# <img src="toyexample_nicer.png" alt="drawing" width="600"/>

# %%
costs = np.array([[maxi,10,maxi,maxi,maxi,maxi,maxi,maxi],
                 [maxi,maxi,10,25,maxi,maxi,maxi,maxi],
                 [maxi,10,maxi,15,5,7,maxi,maxi],
                 [maxi,25,15,maxi,5,maxi,4,maxi],
                 [maxi,maxi,5,5,maxi,15,20,maxi],
                 [maxi,maxi,7,maxi,15,maxi,5,6],
                 [maxi,maxi,maxi,4,20,5,maxi,10],
                 [0,maxi,maxi,maxi,maxi,maxi,maxi,maxi]])
nodes = [str(i+1) for i in range(8)]

# %%
tree = Tree()
node_id = 1

# %time Little(costs,0)
# Out:
# Wall time: 46 ms

# %%
Path(tree)
# Out:
# Found optimal tour!
# 1 -> 2 -> 3 -> 5 -> 4 -> 7 -> 6 -> 8 -> 1
# Total cost : 45.0s

# %% [markdown]
# ### >> From csv

# %%
costs = np.genfromtxt('villes.csv', delimiter=';')
costs = np.array(costs, dtype=float)

# %%
costs = np.nan_to_num(costs, nan=np.inf)
nodes = ['Bordeaux','Lyon','Nantes','Paris']

# %%
costs
# Out:
# array([[ inf, 780., 320., 580.],
#        [780.,  inf, 700., 460.],
#        [320., 700.,  inf, 380.],
#        [580., 460., 380.,  inf]])

# %%
maxi = np.inf
tree = Tree()
node_id = 1

# %time Little(costs,0)
# Out:
# Wall time: 6 ms

# %%
tree.show()
# Out:
# Bordeaux
# ├── Bordeaux!Nantes 1820.0
# │   ├── Bordeaux!Paris 1940.0
# │   │   ├── Bordeaux!Lyon inf
# │   │   └── Lyon 1940.0
# │   │       ├── Lyon!Paris 2180.0
# │   │       │   ├── Lyon!Nantes inf
# │   │       │   └── Nantes 2440.0
# │   │       │       ├── Nantes!Paris inf
# │   │       │       │   ├── Bordeaux inf
# │   │       │       │   └── Nantes!Bordeaux inf
# │   │       │       └── Paris 2440.0
# │   │       │           ├── Bordeaux 2440.0
# │   │       │           └── Paris!Bordeaux inf
# │   │       └── Paris 1940.0
# │   │           ├── Nantes 1940.0
# │   │           │   ├── Bordeaux 1940.0
# │   │           │   └── Nantes!Bordeaux inf
# │   │           └── Paris!Nantes inf
# │   │               ├── Bordeaux inf
# │   │               └── Paris!Bordeaux inf
# │   └── Paris 2060.0
# │       ├── Lyon 2060.0
# │       │   ├── Lyon!Nantes inf
# │       │   │   ├── Bordeaux inf
# │       │   │   └── Lyon!Bordeaux inf
# │       │   └── Nantes 2060.0
# │       │       ├── Bordeaux 2060.0
# │       │       └── Nantes!Bordeaux inf
# │       └── Paris!Lyon 2300.0
# │           ├── Nantes 2440.0
# │           │   ├── Lyon 2440.0
# │           │   │   ├── Bordeaux 2440.0
# │           │   │   └── Lyon!Bordeaux inf
# │           │   └── Nantes!Lyon inf
# │           │       ├── Bordeaux inf
# │           │       └── Nantes!Bordeaux inf
# │           └── Paris!Nantes inf
# └── Nantes 1820.0
#     ├── Nantes!Paris 2060.0
#     │   ├── Lyon 2060.0
#     │   │   ├── Lyon!Paris inf
#     │   │   │   ├── Bordeaux inf
#     │   │   │   └── Lyon!Bordeaux inf
#     │   │   └── Paris 2060.0
#     │   │       ├── Bordeaux 2060.0
#     │   │       └── Paris!Bordeaux inf
#     │   └── Nantes!Lyon inf
#     └── Paris 1940.0
#         ├── Lyon 1940.0
#         │   ├── Bordeaux 1940.0
#         │   └── Lyon!Bordeaux inf
#         └── Paris!Lyon inf
#             ├── Bordeaux inf
#             └── Paris!Bordeaux inf

# %%
Path(tree)
# Out:
# Found optimal tour!
# Bordeaux -> Lyon -> Paris -> Nantes -> Bordeaux
# Total cost : 1940.0s

# %% [markdown]
# **Conclusion :** L'algorithme de Little semble fonctionner très correctement sur des problèmes de petite taille. La résolution est quasi instantanée et nous avons été agréablement surpris du peu de branches explorées, dû  à la forme du problème.
#
# Cela nous donne de bons espoirs quant à la possibilité de résoudre notre problème à 26 checkpoints, malgré que l'algorithme de Little soit censé exploser en complexité bien avant les 26 noeuds

# %% [markdown]
# # Integer Linear Programming

# %% [markdown]
# Nous allons maintenant mettre en place des méthodes de PLNE afin de résoudre notre problème voyageur de checkpoints.
#
# Nous utiliserons ici deux modélisations différentes :
#
# * La modélisation Miller-Tucker-Zemlin
# * La modélisation Dantzig-Fulkerson-Johnson
#
# On se doute d'ores et déjà que la seconde modélisation sera très rapidement impossible à faire tourner, puisque le nombre de contraintes augmente de façon exponentielle. Il pourra cependant être intéressant de comparer l'efficacité des deux modèles sunr des instances plus petites du problème.

# %%
from pulp import *

# %%
nodes = [i for i in range(8)]
maxi = np.inf
costs = np.array([[maxi,10,maxi,maxi,maxi,maxi,maxi,maxi],
                 [maxi,maxi,10,25,maxi,maxi,maxi,maxi],
                 [maxi,10,maxi,15,5,7,maxi,maxi],
                 [maxi,25,15,maxi,5,maxi,4,maxi],
                 [maxi,maxi,5,5,maxi,15,20,maxi],
                 [maxi,maxi,7,maxi,15,maxi,5,6],
                 [maxi,maxi,maxi,4,20,5,maxi,10],
                 [0,maxi,maxi,maxi,maxi,maxi,maxi,maxi]])

# %% [markdown]
# ## Miller-Tucker-Zemlin

# %%
def solveILP_MTZ(nodes, costs , maxi):
    
    distances = dict(((i,j),costs[i,j]) for i in nodes for j in nodes if i!=j and costs[i,j] != maxi )
    
    prob = LpProblem('TrackmaniaSalesmanProblem', LpMinimize) #Define the problem
    
    x = LpVariable.dicts('x',distances, 0,1,LpBinary) #Decision variables
    
    #The objective
    cost = lpSum([x[(i,j)]*distances[(i,j)] for (i,j) in distances])
    prob+=cost
    
    #Constraints
    for k in nodes:
        #every site has exactly one inbound connection
        prob+= lpSum([ x[(i,k)] for i in nodes if (i,k) in x]) ==1
        #every site has exactly one outbound connection
        prob+=lpSum([ x[(k,i)] for i in nodes if (k,i) in x]) ==1
        
    #We need to keep track of the order in the tour to eliminate the possibility of subtours
    u = LpVariable.dicts('u', nodes, 0, len(nodes)-1, LpInteger)
    
    #Subtour elimination
    N=len(nodes)
    for i in nodes:
        for j in nodes:
            if i != j and (i != 0 and j!= 0) and (i,j) in x:
                prob += u[i] - u[j] <= (N)*(1-x[(i,j)]) - 1
                
    # %time prob.solve()
    print(LpStatus[prob.status])
    
"""    
    #Best tour print
    nodes_left = nodes.copy()
    org = 0
    tour=[]
    tour.append(nodes_left.pop( nodes_left.index(org)))

    final_cost = 0
    
    while len(nodes_left) > 0:

        for k in nodes_left:
            try :
                if x[(org,k)].varValue ==1:
                    tour.append( nodes_left.pop( nodes_left.index(k)))
                    final_cost += costs[org,k]
                    org=k
                    break
            except:
                pass

    tour.append(0)

    tour_legs = [distances[(tour[i-1], tour[i])] for i in range(1,len(tour))]

    print('Found optimal tour!')
    tour_str = [str(tour[i]) for i in range(len(tour))]
    print(' -> '.join(tour_str))
    print('Total cost : {}s'.format(final_cost))
"""
# Out:
# "    \n    #Best tour print\n    nodes_left = nodes.copy()\n    org = 0\n    tour=[]\n    tour.append(nodes_left.pop( nodes_left.index(org)))\n\n    final_cost = 0\n    \n    while len(nodes_left) > 0:\n\n        for k in nodes_left:\n            try :\n                if x[(org,k)].varValue ==1:\n                    tour.append( nodes_left.pop( nodes_left.index(k)))\n                    final_cost += costs[org,k]\n                    org=k\n                    break\n            except:\n                pass\n\n    tour.append(0)\n\n    tour_legs = [distances[(tour[i-1], tour[i])] for i in range(1,len(tour))]\n\n    print('Found optimal tour!')\n    tour_str = [str(tour[i]) for i in range(len(tour))]\n    print(' -> '.join(tour_str))\n    print('Total cost : {}s'.format(final_cost))\n"

# %%
solveILP_MTZ(nodes, costs, maxi)
# Out:
# Wall time: 21 ms
# Optimal

# %% [markdown]
# ## Dantzig–Fulkerson–Johnson

# %%
def solveILP_DFJ(nodes, costs , maxi):
    
    distances = dict(((i,j),costs[i,j]) for i in nodes for j in nodes if i!=j and costs[i,j] != maxi )
    
    prob = LpProblem('TrackmaniaSalesmanProblem', LpMinimize) #Define the problem
    
    x = LpVariable.dicts('x',distances, 0,1,LpBinary) #Decision variables
    
    #The objective
    cost = lpSum([x[(i,j)]*distances[(i,j)] for (i,j) in distances])
    prob+=cost
    
    #Constraints
    for k in nodes:
        #every site has exactly one inbound connection
        prob+= lpSum([ x[(i,k)] for i in nodes if (i,k) in x]) ==1
        #every site has exactly one outbound connection
        prob+=lpSum([ x[(k,i)] for i in nodes if (k,i) in x]) ==1
        
    
    #Subtour elimination         
    for subset in powerset(nodes):
        if(len(subset)>=2 and len(subset)<=len(nodes)-1):
            prob += lpSum([ x[(i,j)] for i in subset for j in subset if i!=j and costs[i,j] != maxi]) <= len(subset)-1
            
    # %time prob.solve()
    print(LpStatus[prob.status])
    
    
    #Best tour print
    nodes_left = nodes.copy()
    org = 0
    tour=[]
    tour.append(nodes_left.pop( nodes_left.index(org)))
    
    final_cost = 0 
    
    while len(nodes_left) > 0:

        for k in nodes_left:
            try :
                if x[(org,k)].varValue ==1:
                    tour.append( nodes_left.pop( nodes_left.index(k)))
                    final_cost += costs[org,k]
                    org=k
                    break
            except:
                pass

    tour.append(0)

    tour_legs = [distances[(tour[i-1], tour[i])] for i in range(1,len(tour))]

    print('Found optimal tour!')
    tour_str = [str(tour[i]) for i in range(len(tour))]
    print(' -> '.join(tour_str))
    print('Total cost : {}s'.format(final_cost))

# %%
def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

# %%
solveILP_DFJ(nodes, costs, maxi)
# Out:
# Wall time: 32.2 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 4 -> 3 -> 6 -> 5 -> 7 -> 0
# Total cost : 45.0s

# %% [markdown]
# **Conclusion :** Nos deux algorithmes fonctionnent correctement sur notre exemple jouet et s'exécutent en un temps comparable. On notera également que tous les algorithmes retournent la même réponse, ce qui est plutôt rassurant quant à la bonne qulité de ces derniers

# %% [markdown]
# # Get Real Data in

# %%
maxi = 30
data = pd.read_excel('Données checkpoints E02.xlsx', index_col=0)[0:27].fillna(maxi)

# %%
data[data == 30.00] = np.inf
data[data == 0.00] = np.inf
data.iloc[26][0] = 0
data
# Out:
#               0      1      2      3      4      5      6      7      8   \
# Checkpoints
# 0            inf   9.65    inf  18.23  13.19   9.17    inf    inf    inf
# 1            inf    inf   4.43   9.50   5.09   8.84    inf    inf    inf
# 2            inf   4.25    inf  13.75   9.40  13.35    inf    inf    inf
# 3            inf   9.87  14.42    inf  12.62  17.17    inf    inf    inf
# 4            inf   4.89   5.76  12.42    inf  10.23  13.65   7.14    inf
# 5            inf   8.87   7.60    inf  10.10    inf  11.87   9.78    inf
# 6            inf   7.01  11.71    inf   8.35  12.49    inf  14.13    inf
# 7            inf   6.76   9.18  11.39   3.42  10.30  14.42    inf   8.57
# 8            inf    inf    inf    inf    inf    inf    inf   9.14    inf
# 9            inf    inf    inf    inf    inf    inf    inf    inf  11.91
# 10           inf    inf    inf    inf    inf    inf    inf    inf  12.00
# 11           inf    inf    inf    inf    inf    inf    inf  12.00   6.94
# 12           inf    inf    inf    inf    inf    inf    inf   4.57  12.00
# 13           inf    inf    inf    inf    inf    inf    inf    inf  13.00
# 14           inf    inf    inf    inf    inf    inf    inf    inf    inf
# 15           inf    inf    inf    inf    inf    inf    inf    inf    inf
# 16           inf    inf    inf    inf    inf    inf    inf    inf    inf
# 17           inf    inf    inf    inf    inf    inf    inf    inf   8.00
# 18           inf    inf    inf    inf    inf    inf    inf    inf   4.00
# 19           inf    inf    inf    inf    inf    inf    inf    inf   8.51
# 20           inf    inf    inf    inf    inf    inf    inf    inf    inf
# 21           inf    inf    inf    inf    inf    inf    inf    inf    inf
# 22           inf   7.00   6.47    inf   7.00  12.00   6.67   8.50    inf
# 23           inf  13.00  12.00   9.30  12.00    inf    inf  15.00    inf
# 24           inf    inf    inf    inf    inf    inf    inf    inf    inf
# 25           inf    inf    inf    inf    inf    inf    inf    inf    inf
# 26           0.0    inf    inf    inf    inf    inf    inf    inf    inf
#
#                 9   ...     17     18     19     20     21     22     23  \
# Checkpoints         ...
# 0              inf  ...    inf    inf    inf    inf    inf    inf    inf
# 1              inf  ...    inf    inf    inf    inf    inf    inf    inf
# 2              inf  ...    inf    inf    inf    inf    inf    inf    inf
# 3              inf  ...    inf    inf    inf    inf    inf    inf    inf
# 4              inf  ...    inf    inf    inf    inf    inf    inf    inf
# 5              inf  ...    inf    inf    inf    inf    inf    inf    inf
# 6              inf  ...  10.61    inf    inf    inf    inf    inf    inf
# 7            10.09  ...    inf    inf    inf    inf   9.54    inf   6.89
# 8            11.73  ...    inf   3.22    inf    inf    inf    inf   9.00
# 9              inf  ...    inf  13.00    inf    inf  12.00  12.00   4.77
# 10            3.50  ...    inf  13.00    inf    inf    inf    inf   7.14
# 11            8.66  ...    inf   7.54    inf    inf    inf    inf   8.00
# 12            6.92  ...   8.00   6.02  10.00    inf   8.00  11.12    inf
# 13             inf  ...    inf    inf    inf    inf    inf    inf    inf
# 14             inf  ...    inf    inf    inf    inf    inf    inf    inf
# 15             inf  ...    inf    inf    inf    inf    inf    inf  13.00
# 16             inf  ...   9.55    inf    inf  11.50   5.56    inf    inf
# 17             inf  ...    inf   5.95   7.38   4.13   6.00  15.00  15.00
# 18             inf  ...   6.40    inf   7.46    inf  10.00   9.00  15.00
# 19           11.42  ...   8.00   7.22    inf   8.73   5.98  14.00  14.26
# 20             inf  ...   4.50    inf   9.63    inf   5.80    inf    inf
# 21           11.00  ...   6.00    inf    inf   5.67    inf   8.21  13.00
# 22             inf  ...    inf    inf    inf    inf   7.81    inf   9.91
# 23             inf  ...    inf    inf    inf    inf    inf  10.71    inf
# 24             inf  ...    inf    inf    inf    inf    inf    inf  13.23
# 25             inf  ...    inf    inf    inf    inf    inf    inf    inf
# 26             inf  ...    inf    inf    inf    inf    inf    inf    inf
#
#                 24     25     26
# Checkpoints
# 0             9.77  16.66    inf
# 1             8.56  21.64   8.55
# 2             7.63  17.21  12.80
# 3            12.91    inf  16.27
# 4             8.99    inf  11.33
# 5            10.83  11.01  17.17
# 6              inf    inf  15.10
# 7             7.49    inf    inf
# 8              inf    inf    inf
# 9            15.00    inf    inf
# 10           15.00    inf    inf
# 11             inf    inf    inf
# 12             inf    inf    inf
# 13            9.00  10.00    inf
# 14            4.04  10.00    inf
# 15           10.00   6.00    inf
# 16             inf   7.00  15.00
# 17             inf  10.00  20.00
# 18             inf   6.00    inf
# 19             inf  11.51  15.00
# 20             inf    inf  20.00
# 21             inf   8.00  15.00
# 22            8.00    inf    inf
# 23           12.95    inf    inf
# 24             inf   7.23    inf
# 25            7.49    inf  11.94
# 26             inf    inf    inf
#
# [27 rows x 27 columns]

# %% [markdown]
# ## > Solve with Little

# %% [markdown]
# Comme nous ne pouvions pas forcément nous y attendre, l'algorithme de Little est tout à fait capable de résoudre notre problème de voyageur de checkpoints à 26 sommets.
#
# La résolution du problème est loin d'être rapide (Environ 5 minutes sur nos machines) mais le chemin retourné est correct et correspond exactement au résultat obtenu par Wirtual, que nous essayons de reproduire ici.

# %%
costs = data.values.astype(float)
nodes = [str(i) for i in range(27)]

# %%
maxi = np.inf
tree = Tree()
node_id = 1

#%time Little(costs,0)

# %%
#Path(tree)

# %% [markdown]
# ## > Solve with ILP

# %% [markdown]
# Là où l'algorithme de Little a commencé à exploser en complexité lors de la résolution de ce problème, la modélisation sous forme de programme linéaire en nombres entiers "Miller-Tucker-Zemlin" s'exécute toujours en un temps remarquablement court.
#
# Il est encore une fois intéressant de noter la bonne concordance des nos résultats sur ces deux approches différentes

# %%
maxi = 30
data = pd.read_excel('Données checkpoints E02.xlsx', index_col=0)[0:27].fillna(maxi)
data[data == 0.00] = maxi
data.iloc[26][0] = 0
costs = data.values
nodes = [i for i in range(27)]

# %%
solveILP_MTZ(nodes, costs, maxi)
# Out:
# Wall time: 1.2 s
# Optimal

# %% [markdown]
# Contrairement à notre autre modélisation PLNE, le modèle Dantzig–Fulkerson–Johnson n'est pas caoable de résoudre un problème de cette (faible) taille.

# %%
#solveILP_DFJ(nodes, costs, maxi)

# %% [markdown]
# # Performance comparison
#
# ___
#
# La résolution de notre problème initial ci-dessus nous a permis d'avoir un premier ordre d'idée de la performance de chacun de nos algorithmes.
# * La modélisation PLNE Miller-Tucker-Zemlin est la plus efficace sur des problèmes de taille 26
# * L'algorithme de Little semble être particulièrement efficace sur des problèmes de petite taille
# * La modélisation PLNE Dantzig-Fulkerson-Johnson explose avant les 26 noeuds, mais quand ? Est-elle à un moment plus efficace que la modélisation MTZ
#
# Afin de comparer nos différents algorithmes sur ces problèmes majoritairement vides, nous allons essayer ci-dessous de générer des instances aléatoires de circuits possibles, puis comparer l'efficacité temporelle de nos différentes approches.
#
# Pour correspondre à notre problème, ces circuits devaient avoir un certain nombre de propriétés :
# * **Retour gratuit au départ :** Comme expliqué auparavant, cela nous permet de résoudre notre problème comme si il s'agissait d'un problème de voyageur de commerce, bine que le circuit ne soit pas bouclant. Le sommet de départ n'est accessible que depuis le sommet final, et ce dernier ne peut rejoindre aucun autre sommet.
# * **Faisabilité :** Bien que générés aléatoirement, ces circuits doivent rester faisables. Une façon assez simple de réaliser cette condition est de partir de l'idée que la numérotation des checkpoints correspond à l'ordre dans lequel un joueur normal les prendrait. Ainsi, le sommet $i$ peut toujours rejoindre le sommet $i+1$, et dans une majorité des cas le sommet $i-1$.
# * **Cuts :** Afin de rendre notre problème intéressant et d'éviter que le meilleur chemin soit la voie "normale", nous permettrons à quelques checkpoints, minoritaires, de pouvoir communiquer avec des sommets autres que ses voisins. Nous avons réprti ces "cuts" en trois catégories temporelles. Un cut rapide n'est pas forcément toujours intéressant puisqu'il peut faire perdre du temps plus tard dans le circuit et inversement.

# %% [markdown]
# ## > Random costs generation

# %%
def generateCosts(n):
    
    maxi = np.inf
    proba = [0.7,0.1,0.1,0.1]
    
    costs = np.zeros(n*n).reshape(n,n)+maxi
    costs = costs.astype("float")
    #As our problem isn't really a tour, we force it with a free come-back from finish to start
    costs[n-1, 0] = 0
        
    #Chekpoints numbers correspond to their order on a "normal" run
    #Hence, almost every checkpoint should be able to communicate with its predecessor, but some can't 
    #By allowing every checkpoint to communicate whith its successor we are making sure that the problem is feasible
    
    for i in range(n):
        
        #Successor
        if(i<n-1):
            costs[i,i+1] = abs(2*np.random.randn()+10)
        #Predecessor
        if(i>=2):
            costs[i,i-1] = np.random.choice([maxi,abs(6*np.random.randn()+12)], p=[0.2,0.8])
        
        for j in range(1,n): #We're starting at index 1 to make sure only the last checkpoint can get back to start
            
            fast_cut = abs(np.random.rand()+4)
            average_cut = abs(3*np.random.rand()+10)
            long_cut = abs(np.random.rand()+15)
            
            if(j != i-1 and j!=i and j!= i+1):#Let's not overwrite what we did before
                dist= abs(j-i)
                costs[i,j] = np.random.choice([maxi,long_cut, average_cut, fast_cut], p=proba)
            
    return costs

# %%
n=10
costs = generateCosts(n)
nodes = [str(i) for i in range(n)]

# %%
nodes = [str(i) for i in range(n)]
maxi = np.inf
tree = Tree()
node_id = 1

# %time Little(costs,0)
Path(tree)
# Out:
# Wall time: 274 ms
# Found optimal tour!
# 0 -> 7 -> 3 -> 2 -> 4 -> 5 -> 1 -> 6 -> 8 -> 9 -> 0
# Total cost : 78.22583679689906s

# %%
nodes = [i for i in range(n)]
solveILP_MTZ(nodes, costs, maxi)
# Out:
# Wall time: 51 ms
# Optimal

# %%
solveILP_DFJ(nodes, costs, maxi)
# Out:
# Wall time: 157 ms
# Optimal
# Found optimal tour!
# 0 -> 7 -> 3 -> 2 -> 4 -> 5 -> 1 -> 6 -> 8 -> 9 -> 0
# Total cost : 78.22583679689905s

# %% [markdown]
# On remarquera encore une fois la bonne concordance de nos résultats sur cette matrices générées aléatoirement.

# %% [markdown]
# ## > Timing solvers executions

# %% [markdown]
# Afin de correctement comparer nos algorithmes, nous utiliserons les morceaux de code ci-dessous qui nous permettent de générer nSample échatillons de tests. Chacun de ces tests consiste à chronometrer le temps de résolution du problème avec chacun des algorithmes, pour des problèmes montant graduellement en taille.
#
# Afin de palier au caractère aléatoire de nos matrices, ces dernières seront genérées à priori et utilisées de la même façon pour chacun des algorithmes.
#
# Afin de ne pas faire brûler nos machines, nous avons décidé d'arrêter le test dès que le temps de résolution dépassait un certain palier. Nous enregistrons également tous les résulats au fur et à mesure, ce qui nous permettra de présenter nos conclusions sans que vous ayez à laisser tourner votre machine pendant des heures.
#
# **PS :** Afin de ne pas biaiser les résulats, nous commentons toutes les lignes d'affichage de solution de nos modèles PLNE.

# %% [markdown]
# ### >> Constants

# %%
nSamples = 20
nNodes = 8

# %% [markdown]
# ### >> Generate cost matrices

# %%
for idx in range(nSamples):
    for n in range(3, nNodes+1):
        costs = generateCosts(n)
        np.savetxt("./matrices/{}-{}.csv".format(idx,n), costs, delimiter=";")

# %% [markdown]
# ### >> Timing Little Execution

# %%
isLittleDying = False
littleResults = np.zeros(nSamples*(nNodes-2)).reshape(nSamples, nNodes-2)+1000

for idx in range(nSamples):
    for n in range(3,nNodes+1):
        
        if not isLittleDying:
            
            print("N° échantillon : {} | Nombre de noeuds : {}".format(idx,n))
            
            costs = np.genfromtxt('./matrices/{}-{}.csv'.format(idx,n), delimiter=';')
            #costs = np.array(costs, dtype=float)
            #costs = np.nan_to_num(costs, nan=np.inf)

            nodes = [str(i) for i in range(n)]
            maxi = np.inf
            tree = Tree()
            node_id = 1

            start = time.time()
            Little(costs,0)
            end = time.time()
            
            if(end-start > 30):
                littleResults[idx, n-3] = end-start
                isLittleDying = True
            else:
                littleResults[idx, n-3] = end-start
            print("-> Temps : {}s".format(end-start))
            
    isLittleDying = False
    
np.savetxt("./results/Little-{}-{}.csv".format(nSamples,nNodes), littleResults, delimiter=";")
# Out:
# N° échantillon : 0 | Nombre de noeuds : 3
# -> Temps : 0.0010006427764892578s
# N° échantillon : 0 | Nombre de noeuds : 4
# -> Temps : 0.0020003318786621094s
# N° échantillon : 0 | Nombre de noeuds : 5
# -> Temps : 0.002000093460083008s
# N° échantillon : 0 | Nombre de noeuds : 6
# -> Temps : 0.0060007572174072266s
# N° échantillon : 0 | Nombre de noeuds : 7
# -> Temps : 0.027005434036254883s
# N° échantillon : 0 | Nombre de noeuds : 8
# -> Temps : 0.05501198768615723s
# N° échantillon : 1 | Nombre de noeuds : 3
# -> Temps : 0.0010001659393310547s
# N° échantillon : 1 | Nombre de noeuds : 4
# -> Temps : 0.0009996891021728516s
# N° échantillon : 1 | Nombre de noeuds : 5
# -> Temps : 0.0009999275207519531s
# N° échantillon : 1 | Nombre de noeuds : 6
# -> Temps : 0.012002706527709961s
# N° échantillon : 1 | Nombre de noeuds : 7
# -> Temps : 0.013003349304199219s
# N° échantillon : 1 | Nombre de noeuds : 8
# -> Temps : 0.06401491165161133s
# N° échantillon : 2 | Nombre de noeuds : 3
# -> Temps : 0.0s
# N° échantillon : 2 | Nombre de noeuds : 4
# -> Temps : 0.0010001659393310547s
# N° échantillon : 2 | Nombre de noeuds : 5
# -> Temps : 0.0010008811950683594s
# N° échantillon : 2 | Nombre de noeuds : 6
# -> Temps : 0.005001068115234375s
# N° échantillon : 2 | Nombre de noeuds : 7
# -> Temps : 0.017004013061523438s
# N° échantillon : 2 | Nombre de noeuds : 8
# -> Temps : 0.17503881454467773s
# N° échantillon : 3 | Nombre de noeuds : 3
# -> Temps : 0.0010006427764892578s
# N° échantillon : 3 | Nombre de noeuds : 4
# -> Temps : 0.0019998550415039062s
# N° échantillon : 3 | Nombre de noeuds : 5
# -> Temps : 0.004000663757324219s
# N° échantillon : 3 | Nombre de noeuds : 6
# -> Temps : 0.008001565933227539s
# N° échantillon : 3 | Nombre de noeuds : 7
# -> Temps : 0.03500795364379883s
# N° échantillon : 3 | Nombre de noeuds : 8
# -> Temps : 0.026005268096923828s
# N° échantillon : 4 | Nombre de noeuds : 3
# -> Temps : 0.0010006427764892578s
# N° échantillon : 4 | Nombre de noeuds : 4
# -> Temps : 0.0009992122650146484s
# N° échantillon : 4 | Nombre de noeuds : 5
# -> Temps : 0.002000093460083008s
# N° échantillon : 4 | Nombre de noeuds : 6
# -> Temps : 0.005001068115234375s
# N° échantillon : 4 | Nombre de noeuds : 7
# -> Temps : 0.022005558013916016s
# N° échantillon : 4 | Nombre de noeuds : 8
# -> Temps : 0.06501460075378418s
# N° échantillon : 5 | Nombre de noeuds : 3
# -> Temps : 0.0010001659393310547s
# N° échantillon : 5 | Nombre de noeuds : 4
# -> Temps : 0.00099945068359375s
# N° échantillon : 5 | Nombre de noeuds : 5
# -> Temps : 0.005000114440917969s
# N° échantillon : 5 | Nombre de noeuds : 6
# -> Temps : 0.008002758026123047s
# N° échantillon : 5 | Nombre de noeuds : 7
# -> Temps : 0.01100301742553711s
# N° échantillon : 5 | Nombre de noeuds : 8
# -> Temps : 0.06301355361938477s
# N° échantillon : 6 | Nombre de noeuds : 3
# -> Temps : 0.0010004043579101562s
# N° échantillon : 6 | Nombre de noeuds : 4
# -> Temps : 0.0009992122650146484s
# N° échantillon : 6 | Nombre de noeuds : 5
# -> Temps : 0.00400090217590332s
# N° échantillon : 6 | Nombre de noeuds : 6
# -> Temps : 0.009002923965454102s
# N° échantillon : 6 | Nombre de noeuds : 7
# -> Temps : 0.025005578994750977s
# N° échantillon : 6 | Nombre de noeuds : 8
# -> Temps : 0.010003089904785156s
# N° échantillon : 7 | Nombre de noeuds : 3
# -> Temps : 0.0s
# N° échantillon : 7 | Nombre de noeuds : 4
# -> Temps : 0.0020008087158203125s
# N° échantillon : 7 | Nombre de noeuds : 5
# -> Temps : 0.003999948501586914s
# N° échantillon : 7 | Nombre de noeuds : 6
# -> Temps : 0.005001544952392578s
# N° échantillon : 7 | Nombre de noeuds : 7
# -> Temps : 0.01600360870361328s
# N° échantillon : 7 | Nombre de noeuds : 8
# -> Temps : 0.07701635360717773s
# N° échantillon : 8 | Nombre de noeuds : 3
# -> Temps : 0.0010006427764892578s
# N° échantillon : 8 | Nombre de noeuds : 4
# -> Temps : 0.0040013790130615234s
# N° échantillon : 8 | Nombre de noeuds : 5
# -> Temps : 0.0020003318786621094s
# N° échantillon : 8 | Nombre de noeuds : 6
# -> Temps : 0.009002208709716797s
# N° échantillon : 8 | Nombre de noeuds : 7
# -> Temps : 0.02400517463684082s
# N° échantillon : 8 | Nombre de noeuds : 8
# -> Temps : 0.08401799201965332s
# N° échantillon : 9 | Nombre de noeuds : 3
# -> Temps : 0.0009996891021728516s
# N° échantillon : 9 | Nombre de noeuds : 4
# -> Temps : 0.0009996891021728516s
# N° échantillon : 9 | Nombre de noeuds : 5
# -> Temps : 0.00400090217590332s
# N° échantillon : 9 | Nombre de noeuds : 6
# -> Temps : 0.00800180435180664s
# N° échantillon : 9 | Nombre de noeuds : 7
# -> Temps : 0.012001514434814453s
# N° échantillon : 9 | Nombre de noeuds : 8
# -> Temps : 0.05501270294189453s
# N° échantillon : 10 | Nombre de noeuds : 3
# -> Temps : 0.0s
# N° échantillon : 10 | Nombre de noeuds : 4
# -> Temps : 0.0010006427764892578s
# N° échantillon : 10 | Nombre de noeuds : 5
# -> Temps : 0.003000497817993164s
# N° échantillon : 10 | Nombre de noeuds : 6
# -> Temps : 0.008002758026123047s
# N° échantillon : 10 | Nombre de noeuds : 7
# -> Temps : 0.014002323150634766s
# N° échantillon : 10 | Nombre de noeuds : 8
# -> Temps : 0.07501626014709473s
# N° échantillon : 11 | Nombre de noeuds : 3
# -> Temps : 0.0010001659393310547s
# N° échantillon : 11 | Nombre de noeuds : 4
# -> Temps : 0.0010001659393310547s
# N° échantillon : 11 | Nombre de noeuds : 5
# -> Temps : 0.004000425338745117s
# N° échantillon : 11 | Nombre de noeuds : 6
# -> Temps : 0.0030002593994140625s
# N° échantillon : 11 | Nombre de noeuds : 7
# -> Temps : 0.04500913619995117s
# N° échantillon : 11 | Nombre de noeuds : 8
# -> Temps : 0.05201148986816406s
# N° échantillon : 12 | Nombre de noeuds : 3
# -> Temps : 0.0010006427764892578s
# N° échantillon : 12 | Nombre de noeuds : 4
# -> Temps : 0.0019998550415039062s
# N° échantillon : 12 | Nombre de noeuds : 5
# -> Temps : 0.009001731872558594s
# N° échantillon : 12 | Nombre de noeuds : 6
# -> Temps : 0.003000020980834961s
# N° échantillon : 12 | Nombre de noeuds : 7
# -> Temps : 0.017004013061523438s
# N° échantillon : 12 | Nombre de noeuds : 8
# -> Temps : 0.05101132392883301s
# N° échantillon : 13 | Nombre de noeuds : 3
# -> Temps : 0.0010004043579101562s
# N° échantillon : 13 | Nombre de noeuds : 4
# -> Temps : 0.0s
# N° échantillon : 13 | Nombre de noeuds : 5
# -> Temps : 0.004001140594482422s
# N° échantillon : 13 | Nombre de noeuds : 6
# -> Temps : 0.003000020980834961s
# N° échantillon : 13 | Nombre de noeuds : 7
# -> Temps : 0.04800987243652344s
# N° échantillon : 13 | Nombre de noeuds : 8
# -> Temps : 0.04501199722290039s
# N° échantillon : 14 | Nombre de noeuds : 3
# -> Temps : 0.0s
# N° échantillon : 14 | Nombre de noeuds : 4
# -> Temps : 0.002000570297241211s
# N° échantillon : 14 | Nombre de noeuds : 5
# -> Temps : 0.00400090217590332s
# N° échantillon : 14 | Nombre de noeuds : 6
# -> Temps : 0.007001161575317383s
# N° échantillon : 14 | Nombre de noeuds : 7
# -> Temps : 0.006001710891723633s
# N° échantillon : 14 | Nombre de noeuds : 8
# -> Temps : 0.03800773620605469s
# N° échantillon : 15 | Nombre de noeuds : 3
# -> Temps : 0.0010004043579101562s
# N° échantillon : 15 | Nombre de noeuds : 4
# -> Temps : 0.0010004043579101562s
# N° échantillon : 15 | Nombre de noeuds : 5
# -> Temps : 0.002000570297241211s
# N° échantillon : 15 | Nombre de noeuds : 6
# -> Temps : 0.00800180435180664s
# N° échantillon : 15 | Nombre de noeuds : 7
# -> Temps : 0.019004106521606445s
# N° échantillon : 15 | Nombre de noeuds : 8
# -> Temps : 0.04901123046875s
# N° échantillon : 16 | Nombre de noeuds : 3
# -> Temps : 0.0010006427764892578s
# N° échantillon : 16 | Nombre de noeuds : 4
# -> Temps : 0.0020003318786621094s
# N° échantillon : 16 | Nombre de noeuds : 5
# -> Temps : 0.0050013065338134766s
# N° échantillon : 16 | Nombre de noeuds : 6
# -> Temps : 0.0070018768310546875s
# N° échantillon : 16 | Nombre de noeuds : 7
# -> Temps : 0.035007476806640625s
# N° échantillon : 16 | Nombre de noeuds : 8
# -> Temps : 0.12402796745300293s
# N° échantillon : 17 | Nombre de noeuds : 3
# -> Temps : 0.0009992122650146484s
# N° échantillon : 17 | Nombre de noeuds : 4
# -> Temps : 0.002000093460083008s
# N° échantillon : 17 | Nombre de noeuds : 5
# -> Temps : 0.01300191879272461s
# N° échantillon : 17 | Nombre de noeuds : 6
# -> Temps : 0.004000663757324219s
# N° échantillon : 17 | Nombre de noeuds : 7
# -> Temps : 0.00800180435180664s
# N° échantillon : 17 | Nombre de noeuds : 8
# -> Temps : 0.15703487396240234s
# N° échantillon : 18 | Nombre de noeuds : 3
# -> Temps : 0.0s
# N° échantillon : 18 | Nombre de noeuds : 4
# -> Temps : 0.0010004043579101562s
# N° échantillon : 18 | Nombre de noeuds : 5
# -> Temps : 0.003000974655151367s
# N° échantillon : 18 | Nombre de noeuds : 6
# -> Temps : 0.005000591278076172s
# N° échantillon : 18 | Nombre de noeuds : 7
# -> Temps : 0.003000020980834961s
# N° échantillon : 18 | Nombre de noeuds : 8
# -> Temps : 0.02200460433959961s
# N° échantillon : 19 | Nombre de noeuds : 3
# -> Temps : 0.0010004043579101562s
# N° échantillon : 19 | Nombre de noeuds : 4
# -> Temps : 0.0019998550415039062s
# N° échantillon : 19 | Nombre de noeuds : 5
# -> Temps : 0.004000663757324219s
# N° échantillon : 19 | Nombre de noeuds : 6
# -> Temps : 0.009001493453979492s
# N° échantillon : 19 | Nombre de noeuds : 7
# -> Temps : 0.013002634048461914s
# N° échantillon : 19 | Nombre de noeuds : 8
# -> Temps : 0.025015830993652344s

# %% [markdown]
# ### >> Timing ILP-MTZ

# %%
isMtzDying = False
mtzResults = np.zeros(nSamples*(nNodes-2)).reshape(nSamples, nNodes-2)+1000

for idx in range(nSamples):
    for n in range(3,nNodes+1):
        
        if not isMtzDying:
            
            print("N° échantillon : {} | Nombre de noeuds : {}".format(idx,n))
            
            costs = np.genfromtxt('./matrices/{}-{}.csv'.format(idx,n), delimiter=';')
            #costs = np.array(costs, dtype=float)
            #costs = np.nan_to_num(costs, nan=np.inf)

            nodes = [i for i in range(n)]
            maxi = np.inf

            start = time.time()
            solveILP_MTZ(nodes, costs, maxi)
            end = time.time()
            
            if(end-start > 60):
                mtzResults[idx, n-3] = end-start
                isMtzDying = True
            else:
                mtzResults[idx, n-3] = end-start
            print("-> Temps : {}s".format(end-start))
            
    isMtzDying = False
    
np.savetxt("./results/ILP-MTZ-{}-{}.csv".format(nSamples,nNodes), mtzResults, delimiter=";")
# Out:
# N° échantillon : 0 | Nombre de noeuds : 3
# Wall time: 17.5 ms
# Optimal
# -> Temps : 0.01851511001586914s
# N° échantillon : 0 | Nombre de noeuds : 4
# Wall time: 14 ms
# Optimal
# -> Temps : 0.016004562377929688s
# N° échantillon : 0 | Nombre de noeuds : 5
# Wall time: 15 ms
# Optimal
# -> Temps : 0.01700305938720703s
# N° échantillon : 0 | Nombre de noeuds : 6
# Wall time: 16 ms
# Optimal
# -> Temps : 0.017003536224365234s
# N° échantillon : 0 | Nombre de noeuds : 7
# Wall time: 28 ms
# Optimal
# -> Temps : 0.029005765914916992s
# N° échantillon : 0 | Nombre de noeuds : 8
# Wall time: 21 ms
# Optimal
# -> Temps : 0.022005319595336914s
# N° échantillon : 1 | Nombre de noeuds : 3
# Wall time: 15 ms
# Optimal
# -> Temps : 0.01600337028503418s
# N° échantillon : 1 | Nombre de noeuds : 4
# Wall time: 15 ms
# Optimal
# -> Temps : 0.015003442764282227s
# N° échantillon : 1 | Nombre de noeuds : 5
# Wall time: 16 ms
# Optimal
# -> Temps : 0.016004085540771484s
# N° échantillon : 1 | Nombre de noeuds : 6
# Wall time: 19 ms
# Optimal
# -> Temps : 0.019003629684448242s
# N° échantillon : 1 | Nombre de noeuds : 7
# Wall time: 19 ms
# Optimal
# -> Temps : 0.020004749298095703s
# Optimal
# -> Temps : 0.020003557205200195s
# N° échantillon : 18 | Nombre de noeuds : 7
# Wall time: 20 ms
# Optimal
# -> Temps : 0.021005868911743164s
# N° échantillon : 18 | Nombre de noeuds : 8
# Wall time: 26 ms
# Optimal
# -> Temps : 0.02800607681274414s
# N° échantillon : 19 | Nombre de noeuds : 3
# Wall time: 19 ms
# Optimal
# -> Temps : 0.020003557205200195s
# N° échantillon : 19 | Nombre de noeuds : 4
# Wall time: 19 ms
# Optimal
# -> Temps : 0.020005226135253906s
# N° échantillon : 19 | Nombre de noeuds : 5
# Wall time: 19 ms
# Optimal
# -> Temps : 0.020003080368041992s
# N° échantillon : 19 | Nombre de noeuds : 6
# Wall time: 23 ms
# Optimal
# -> Temps : 0.024004459381103516s
# N° échantillon : 19 | Nombre de noeuds : 7
# Wall time: 28 ms
# Optimal
# -> Temps : 0.030007123947143555s
# N° échantillon : 19 | Nombre de noeuds : 8
# Wall time: 21 ms
# Optimal
# -> Temps : 0.023006200790405273s

# %% [markdown]
# ### >> Timing ILP-DFJ

# %%
isDfjDying = False
dfjResults = np.zeros(nSamples*(nNodes-2)).reshape(nSamples, nNodes-2)+1000

for idx in range(nSamples):
    for n in range(3,nNodes+1):
        
        if not isDfjDying:
            
            print("N° échantillon : {} | Nombre de noeuds : {}".format(idx,n))
            
            costs = np.genfromtxt('./matrices/{}-{}.csv'.format(idx,n), delimiter=';')
            #costs = np.array(costs, dtype=float)
            #costs = np.nan_to_num(costs, nan=np.inf)

            nodes = [i for i in range(n)]
            maxi = np.inf

            start = time.time()
            solveILP_DFJ(nodes, costs, maxi)
            end = time.time()
            
            if(end-start > 20):
                dfjResults[idx, n-3] = end-start
                isDfjDying = True
            else:
                dfjResults[idx, n-3] = end-start
            print("-> Temps : {}s".format(end-start))
            
    isDfjDying = False
    
np.savetxt("./results/ILP-DFJ-{}-{}.csv".format(nSamples,nNodes), dfjResults, delimiter=";")
# Out:
# N° échantillon : 0 | Nombre de noeuds : 3
# Wall time: 17.8 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 0
# Total cost : 16.26759744464831s
# -> Temps : 0.0187685489654541s
# N° échantillon : 0 | Nombre de noeuds : 4
# Wall time: 17 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 0
# Total cost : 23.820224837006265s
# -> Temps : 0.018002748489379883s
# N° échantillon : 0 | Nombre de noeuds : 5
# Wall time: 16.7 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 0
# Total cost : 41.52072734491007s
# -> Temps : 0.018711090087890625s
# N° échantillon : 0 | Nombre de noeuds : 6
# Wall time: 17 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 5 -> 0
# Total cost : 43.959616418939454s
# -> Temps : 0.020003557205200195s
# N° échantillon : 0 | Nombre de noeuds : 7
# Wall time: 21 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> 0
# Total cost : 61.50760162931169s
# -> Temps : 0.02400684356689453s
# N° échantillon : 0 | Nombre de noeuds : 8
# Wall time: 35 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 5 -> 3 -> 2 -> 4 -> 6 -> 7 -> 0
# Total cost : 56.40648772263384s
# -> Temps : 0.04200863838195801s
# N° échantillon : 1 | Nombre de noeuds : 3
# Wall time: 15 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 ->
ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 0
# Total cost : 41.15761409337355s
# -> Temps : 0.019005537033081055s
# N° échantillon : 16 | Nombre de noeuds : 6
# Wall time: 16 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 5 -> 0
# Total cost : 46.49434907040334s
# -> Temps : 0.01800370216369629s
# N° échantillon : 16 | Nombre de noeuds : 7
# Wall time: 21 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 5 -> 4 -> 6 -> 0
# Total cost : 53.94039038395167s
# -> Temps : 0.024005651473999023s
# N° échantillon : 16 | Nombre de noeuds : 8
# Wall time: 50 ms
# Optimal
# Found optimal tour!
# 0 -> 2 -> 3 -> 4 -> 1 -> 5 -> 6 -> 7 -> 0
# Total cost : 64.7006401687734s
# -> Temps : 0.05801272392272949s
# N° échantillon : 17 | Nombre de noeuds : 3
# Wall time: 15 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 0
# Total cost : 23.31260772806558s
# -> Temps : 0.016005277633666992s
# N° échantillon : 17 | Nombre de noeuds : 4
# Wall time: 15 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 0
# Total cost : 26.32337759805475s
# -> Temps : 0.015003442764282227s
# N° échantillon : 17 | Nombre de noeuds : 5
# Wall time: 19 ms
# Optimal
# Found optimal tour!
# 0 -> 2 -> 1 -> 3 -> 4 -> 0
# Total cost : 40.13378163708869s
# -> Temps : 0.021004915237426758s
# N° échantillon : 17 | Nombre de noeuds : 6
# Wall time: 17 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 5 -> 0
# Total cost : 52.798652419510994s
# -> Temps : 0.020003318786621094s
# N° échantillon : 17 | Nombre de noeuds : 7
# Wall time: 19 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> 0
# Total cost : 60.553693090184055s
# -> Temps : 0.02200627326965332s
# N° échantillon : 17 | Nombre de noeuds : 8
# Wall time: 41 ms
# Optimal
# Found optimal tour!
# 0 -> 4 -> 3 -> 2 -> 1 -> 5 -> 6 -> 7 -> 0
# Total cost : 49.114832537312914s
# -> Temps : 0.04901003837585449s
# N° échantillon : 18 | Nombre de noeuds : 3
# Wall time: 14 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 0
# Total cost : 16.556092153653058s
# -> Temps : 0.015002965927124023s
# N° échantillon : 18 | Nombre de noeuds : 4
# Wall time: 14 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 0
# Total cost : 27.7547464703047s
# -> Temps : 0.01500391960144043s
# N° échantillon : 18 | Nombre de noeuds : 5
# Wall time: 16 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 0
# Total cost : 37.54608261804492s
# -> Temps : 0.01600480079650879s
# N° échantillon : 18 | Nombre de noeuds : 6
# Wall time: 18 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 5 -> 0
# Total cost : 52.02512835349657s
# -> Temps : 0.01900458335876465s
# N° échantillon : 18 | Nombre de noeuds : 7
# Wall time: 20 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> 0
# Total cost : 65.15603640997507s
# -> Temps : 0.023005962371826172s
# N° échantillon : 18 | Nombre de noeuds : 8
# Wall time: 27 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> 7 -> 0
# Total cost : 75.55445727913146s
# -> Temps : 0.033006906509399414s
# N° échantillon : 19 | Nombre de noeuds : 3
# Wall time: 15 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 0
# Total cost : 21.509922186445575s
# -> Temps : 0.015004873275756836s
# N° échantillon : 19 | Nombre de noeuds : 4
# Wall time: 14 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 0
# Total cost : 27.801168209400533s
# -> Temps : 0.014002084732055664s
# N° échantillon : 19 | Nombre de noeuds : 5
# Wall time: 16 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 0
# Total cost : 34.017295326815955s
# -> Temps : 0.01700425148010254s
# N° échantillon : 19 | Nombre de noeuds : 6
# Wall time: 17 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 5 -> 0
# Total cost : 35.958677002716435s
# -> Temps : 0.018003463745117188s
# N° échantillon : 19 | Nombre de noeuds : 7
# Wall time: 24 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> 0
# Total cost : 61.50453134446243s
# -> Temps : 0.027006864547729492s
# N° échantillon : 19 | Nombre de noeuds : 8
# Wall time: 28 ms
# Optimal
# Found optimal tour!
# 0 -> 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> 7 -> 0
# Total cost : 75.4144099873387s
# -> Temps : 0.03500795364379883s

# %%
X = [i for i in range(3,nNodes+1)]
littleArray = np.sum(littleResults , axis=0)/nSamples
mtzArray = np.sum(mtzResults , axis=0)/nSamples
dfjArray = np.sum(dfjResults , axis=0)/nSamples

littleArray = littleArray[littleArray !=1000]
mtzArray = mtzArray[mtzArray !=1000]
dfjArray = dfjArray[dfjArray !=1000]

xLittle = [i for i in range(3,3+len(littleArray))]
xMtz= [i for i in range(3,3+len(mtzArray))]
xDfj = [i for i in range(3,3+len(dfjArray))]

# %% [markdown]
# ## > Printing results

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,9))
plt.style.use('ggplot')
plt.ylabel('Temps en s')
plt.xlabel('Nombre de checkpoints')
plt.title("Comparaison des temps d'exécution")
plt.plot(xLittle,littleArray,xMtz,mtzArray,xDfj,dfjArray)
plt.legend(['Little','MTZ','DFJ'])
plt.savefig('./results/20-8.png')

# %% [markdown]
# Blablater les résulats
#
# <img src="./results/20-8.png" alt="drawing" width="1000"/>
#
# ___
#
# <img src="./results/20-12.png" alt="drawing" width="1000"/>
#
# ___
#
# <img src="./results/3_200.png" alt="drawing" width="1000"/>
#
# ___
#
# <img src="./results/3_200-zoom-MTZ.png" alt="drawing" width="1000"/>

# %% [markdown]
# ## A smarter approach ?
#
# ___
#
# D'après ce que nous avons pu voir ci-dessus, la modélisation DFJ de notre problème était ridiculement peu performante. En éliminant de manière systématique tous le sous circuits possibles, on se retrouve avec ~2^n contraintes pour un problème à n sommets.
#
# Cependant, le problème que nous étudions est particulièrement vide : Chaque sommet ne peut accèder qu'à un nombre réduit de voisins. Ainsi, l'immense majorité des sous-circuits sur lesquels nous itérons sont impossibles.
#
# Aussi, nous mettons ici en place une nouvelle approche du problème, où nous résolvons le problème sans contraintes d'éliminations de sous-circuits, puis éliminons tous les sous circuits trouvés. Cette méthode ne permet pas d'éliminer tous le sous circuits possibles mais uniquement les sous cicruits potentiellement intéressants.

# %%
def solveILP_T(nodes, costs , maxi):
    
    isProblemSolved = False
    forbiddenSubtours = []
    
    
    while not isProblemSolved :
    
        distances = dict(((i,j),costs[i,j]) for i in nodes for j in nodes if i!=j and costs[i,j] != maxi )

        prob = LpProblem('TrackmaniaSalesmanProblem', LpMinimize) #Define the problem

        x = LpVariable.dicts('x',distances, 0,1,LpBinary) #Decision variables

        #The objective
        cost = lpSum([x[(i,j)]*distances[(i,j)] for (i,j) in distances])
        prob+=cost

        #Constraints
        for k in nodes:
            #every site has exactly one inbound connection
            prob+= lpSum([ x[(i,k)] for i in nodes if (i,k) in x]) ==1
            #every site has exactly one outbound connection
            prob+=lpSum([ x[(k,i)] for i in nodes if (k,i) in x]) ==1


        #Subtour elimination         
        for subtour in forbiddenSubtours:
            prob += lpSum([ x[(i,j)] for (i,j) in subtour]) <= len(subtour)-1

        # %time prob.solve()
        print(LpStatus[prob.status])
        
        (isSubtour, subtourList) = detectSubtours(x,nodes)
        
        if not isSubtour:
            isProblemSolved = True
        else:
            print('> Subtours eliminated')
            for subtourFound in subtourList:
                forbiddenSubtours.append([(i,j) for (i,j) in subtourFound ])
"""        
    #Best tour print
    nodes_left = nodes.copy()
    org = 0
    tour=[]
    tour.append(nodes_left.pop( nodes_left.index(org)))
    
    final_cost = 0 
    
    while len(nodes_left) > 0:

        for k in nodes_left:
            try :
                if x[(org,k)].varValue ==1:
                    tour.append( nodes_left.pop( nodes_left.index(k)))
                    final_cost += costs[org,k]
                    org=k
                    break
            except:
                pass

    tour.append(0)

    tour_legs = [distances[(tour[i-1], tour[i])] for i in range(1,len(tour))]

    print('Found optimal tour!')
    tour_str = [str(tour[i]) for i in range(len(tour))]
    print(' -> '.join(tour_str))
    print('Total cost : {}s'.format(final_cost))
"""
# Out:
# "        \n    #Best tour print\n    nodes_left = nodes.copy()\n    org = 0\n    tour=[]\n    tour.append(nodes_left.pop( nodes_left.index(org)))\n    \n    final_cost = 0 \n    \n    while len(nodes_left) > 0:\n\n        for k in nodes_left:\n            try :\n                if x[(org,k)].varValue ==1:\n                    tour.append( nodes_left.pop( nodes_left.index(k)))\n                    final_cost += costs[org,k]\n                    org=k\n                    break\n            except:\n                pass\n\n    tour.append(0)\n\n    tour_legs = [distances[(tour[i-1], tour[i])] for i in range(1,len(tour))]\n\n    print('Found optimal tour!')\n    tour_str = [str(tour[i]) for i in range(len(tour))]\n    print(' -> '.join(tour_str))\n    print('Total cost : {}s'.format(final_cost))\n"

# %%
def detectSubtours(x,nodes):
    
    isSubtour = False

    nodes_left = nodes.copy()
    start = 0
    org = 0
    subtour0=[]
    subtourList=[]


    while len(nodes_left) > 0 and not isSubtour:

        for k in nodes_left:
            try :
                if x[(org,k)].varValue ==1:
                    
                    nodes_left.pop( nodes_left.index(k))
                    subtour0.append((org,k))
                    org=k

                    if k==start and len(subtour0)<len(nodes):
                        isSubtour = True
                    break
            except:
                pass
    
    while len(nodes_left)>0:  
        
        start = nodes_left[0]
        org = nodes_left[0]
        nodes_left.append(nodes_left[0])
        new_subtour = []
        last=0
        
        #print("Start : ", start)
        #print(nodes_left)
        
        while last != start:
            for k in nodes_left:
                try :
                    if x[(org,k)].varValue ==1:
                        
                        #print("(",org,",",k,")")
                        
                        nodes_left.pop( nodes_left.index(k))
                        new_subtour.append((org,k))
                        org=k
                        last=k
                        
                        if k==start:
                            nodes_left.pop( nodes_left.index(start))
                            break
                except:
                    pass
                
        subtourList.append(new_subtour)

    subtourList.append(subtour0)
    
    if not isSubtour:
        print("> No subtours")
        return(False, [])
    else:
        print("> Subtours")
        #print(subtourList)
        return(True, subtourList)

# %% [markdown]
# ### >> Toy example

# %%
nodes = [i for i in range(8)]
maxi = np.inf
costs = np.array([[maxi,10,maxi,maxi,maxi,maxi,maxi,maxi],
                 [maxi,maxi,10,25,maxi,maxi,maxi,maxi],
                 [maxi,10,maxi,15,1,7,maxi,maxi],
                 [maxi,25,15,maxi,5,maxi,4,maxi],
                 [maxi,maxi,5,5,maxi,1,20,maxi],
                 [maxi,maxi,1,maxi,15,maxi,5,6],
                 [maxi,maxi,maxi,4,20,5,maxi,10],
                 [0,maxi,maxi,maxi,maxi,maxi,maxi,maxi]])

# %%
start = time.time()
solveILP_T(nodes, costs, maxi)
end = time.time()
print("Execution Time : ", end-start, 's')
# Out:
# Wall time: 15 ms
# Optimal
# > Subtours
# > Subtours eliminated
# Wall time: 12 ms
# Optimal
# > No subtours
# Execution Time :  0.0290071964263916 s

# %% [markdown]
# ### >> Trackmania example

# %%
maxi = 30
data = pd.read_excel('Données checkpoints E02.xlsx', index_col=0)[0:27].fillna(maxi)
data[data == 0.00] = maxi
data.iloc[26][0] = 0
costs = data.values
nodes = [i for i in range(27)]

# %%
start = time.time()
solveILP_T(nodes, costs, maxi)
end = time.time()
print("Execution Time : ", end-start, 's')
# Out:
# Wall time: 28 ms
# Optimal
# > Subtours
# > Subtours eliminated
# Wall time: 51 ms
# Optimal
# > Subtours
# > Subtours eliminated
# Wall time: 65 ms
# Optimal
# > Subtours
# > Subtours eliminated
# Wall time: 72 ms
# Optimal
# > No subtours
# Execution Time :  0.23705267906188965 s

# %% [markdown]
# **Conclusion :** Nous avons ici pu vérifier que cette nouvelle modélisation fonctionnait bien sur nos deux problèmes de référence. Nos résultats sont cohérents avec ceux retournés par les autres algorithmes et la résolution semble plus rapide !
#
# Là où la modélisation Miller-Tucker-Zemlin prenait 1,30s pour résoudre notre problème, cette nouvelle approche ne prends pas plus de 0,25s.
#
# Nous allons maintenant comparer l'efficacité de cette nouvelle modélisation avec la modélisation Miller-Tucker-Zemlin, qui était notre référence de performance jusqu'alors, sur différentes tailles de circuit.

# %% [markdown]
# ### >> Constants

# %%
nSamples = 10
nNodes = 200
time_limit = 60

# %% [markdown]
# ### >> Generate cost matrices

# %%
for idx in range(nSamples):
    for n in range(3, nNodes+1):
        costs = generateCosts(n)
        np.savetxt("./matrices/{}-{}-MTZvsDFJ.csv".format(idx,n), costs, delimiter=";")

# %% [markdown]
# ### >> Timing ILP-MTZ

# %%
isMtzDying = False
mtzResults = np.zeros(nSamples*(nNodes-2)).reshape(nSamples, nNodes-2)
previous_time = 0

for idx in range(nSamples):
    for n in range(3,nNodes+1):
        
        if not isMtzDying:
            
            print("N° échantillon : {} | Nombre de noeuds : {}".format(idx,n))
            
            costs = np.genfromtxt('./matrices/{}-{}-MTZvsDFJ.csv'.format(idx,n), delimiter=';')
            #costs = np.array(costs, dtype=float)
            #costs = np.nan_to_num(costs, nan=np.inf)

            nodes = [i for i in range(n)]
            maxi = np.inf

            start = time.time()
            solveILP_MTZ(nodes, costs, maxi)
            end = time.time()
            
            if(end-start > time_limit and previous_time>time_limit):
                mtzResults[idx, n-3] = end-start
                isMtzDying = True
            else:
                mtzResults[idx, n-3] = end-start
            previous_time = end-start
            print("-> Temps : {}s".format(end-start))
            
    isMtzDying = False
    
np.savetxt("./results/ILP-MTZ-{}-{}-DUEL.csv".format(nSamples,nNodes), mtzResults, delimiter=";")
# Out:
# N° échantillon : 0 | Nombre de noeuds : 3
# Wall time: 18 ms
# Optimal
# -> Temps : 0.018004655838012695s
# N° échantillon : 0 | Nombre de noeuds : 4
# Wall time: 15 ms
# Optimal
# -> Temps : 0.01600360870361328s
# N° échantillon : 0 | Nombre de noeuds : 5
# Wall time: 15 ms
# Optimal
# -> Temps : 0.016003847122192383s
# N° échantillon : 0 | Nombre de noeuds : 6
# Wall time: 16 ms
# Optimal
# -> Temps : 0.017003774642944336s
# N° échantillon : 0 | Nombre de noeuds : 7
# Wall time: 22 ms
# Optimal
# -> Temps : 0.023006439208984375s
# N° échantillon : 0 | Nombre de noeuds : 8
# Wall time: 43 ms
# Optimal
# -> Temps : 0.044010162353515625s
# N° échantillon : 0 | Nombre de noeuds : 9
# Wall time: 57 ms
# Optimal
# -> Temps : 0.05901360511779785s
# N° échantillon : 0 | Nombre de noeuds : 10
# Wall time: 53 ms
# Optimal
# -> Temps : 0.05601334571838379s
# N° échantillon : 0 | Nombre de noeuds : 11
# Wall time: 102 ms
# Optimal
# -> Temps : 0.10502505302429199s
# N° échantillon : 0 | Nombre de noeuds : 12
# Wall time: 70 ms
# Optimal
# -> Temps : 0.07501769065856934s
# N° échantillon : 0 | Nombre de noeuds : 13
# Wall time: 117 ms
# Optimal
# -> Temps : 0.11902832984924316s
# N° échantillon : 0 | Nombre de noeuds : 14
# Wall time: 85 ms
# Optimal
# -> Temps : 0.09002137184143066s
# N° échantillon : 0 | Nombre de noeuds : 15
# Wall time: 94 ms
# Optimal
# -> Temps : 0.10002446174621582s
# N° échantillon : 0 | Nombre de noeuds : 16
# Wall time: 46 ms
# Optimal
# -> Temps : 0.051012516021728516s
# N° échantillon : 0 | Nombre de noeuds : 17
# Wall time: 95 ms
# Optimal
# -> Temps : 0.10102295875549316s
# N° échantillon : 0 | Nombre de noeuds : 18
# Wall time: 80 ms
# Optimal
# -> Temps : 0.0870201587677002s
# N° échantillon : 0 | Nombre de noeuds : 19
# Wall time: 165 ms
# Optimal
# -> Temps : 0.17103886604309082s
# N° échantillon : 0 | Nombre de noeuds : 20
# Wall time: 537 ms
# Optimal
# -> Temps : 0.5421249866485596s
# N° échantillon : 0 | Nombre de noeuds : 21
# Wall time: 138 ms
# Optimal
# -> Temps : 0.1470329761505127s
# N° échantillon : 0 | Nombre de noeuds : 22
# Wall time: 211 ms
# Optimal
# -> Temps : 0.22155451774597168s
# N° échantillon : 0 | Nombre de noeuds : 23
# Wall time: 694 ms
# Optimal
# -> Temps : 0.7059288024902344s
# N° échantillon : 0 | Nombre de noeuds : 24
# Wall time: 140 ms
# Optimal
# -> Temps : 0.1490340232849121s
# -> Temps : 9.755371570587158s
# N° échantillon : 2 | Nombre de noeuds : 74
# Wall time: 16.4 s
# Optimal
# -> Temps : 16.46659231185913s
# N° échantillon : 2 | Nombre de noeuds : 75
# Wall time: 25.8 s
# Optimal
# -> Temps : 25.86999487876892s
# N° échantillon : 2 | Nombre de noeuds : 76
# Wall time: 20 s
# Optimal
# -> Temps : 20.10219717025757s
# N° échantillon : 2 | Nombre de noeuds : 77
# Wall time: 5.42 s
# Optimal
# -> Temps : 5.5188353061676025s
# N° échantillon : 2 | Nombre de noeuds : 78
# Wall time: 3.8 s
# Optimal
# -> Temps : 3.874481201171875s
# N° échantillon : 2 | Nombre de noeuds : 79
# Wall time: 5.62 s
# Optimal
# -> Temps : 5.6990721225738525s
# N° échantillon : 2 | Nombre de noeuds : 80
# Wall time: 3.26 s
# Optimal
# -> Temps : 3.3419971466064453s
# N° échantillon : 2 | Nombre de noeuds : 81
# Wall time: 9.47 s
# Optimal
# -> Temps : 9.554388046264648s
# N° échantillon : 2 | Nombre de noeuds : 82
# Wall time: 2min 2s
# Optimal
# -> Temps : 122.82112693786621s
# N° échantillon : 2 | Nombre de noeuds : 83
# Wall time: 6.85 s
# Optimal
# -> Temps : 6.931985855102539s
# N° échantillon : 2 | Nombre de noeuds : 84
# Wall time: 5.31 s
# Optimal
# -> Temps : 5.396414279937744s
# N° échantillon : 2 | Nombre de noeuds : 85
# Wall time: 5.94 s
# Optimal
# -> Temps : 6.029886960983276s
# N° échantillon : 2 | Nombre de noeuds : 86
# Wall time: 3.96 s
# Optimal
# -> Temps : 4.056002378463745s
# N° échantillon : 2 | Nombre de noeuds : 87
# Wall time: 3.57 s
# Optimal
# -> Temps : 3.6611437797546387s
# N° échantillon : 2 | Nombre de noeuds : 88
# Wall time: 19.5 s
# Optimal
# -> Temps : 19.596697568893433s
# N° échantillon : 2 | Nombre de noeuds : 89
# Wall time: 13.2 s
# Optimal
# -> Temps : 13.27855110168457s
# N° échantillon : 2 | Nombre de noeuds : 90
# Wall time: 23.7 s
# Optimal
# -> Temps : 23.80650019645691s
# N° échantillon : 2 | Nombre de noeuds : 91
# Wall time: 5.14 s
# Optimal
# -> Temps : 5.240411043167114s
# N° échantillon : 2 | Nombre de noeuds : 92
# Wall time: 14.2 s
# Optimal
# -> Temps : 14.290859937667847s
# N° échantillon : 2 | Nombre de noeuds : 93
# Wall time: 4.55 s
# Optimal
# -> Temps : 4.666295528411865s
# N° échantillon : 2 | Nombre de noeuds : 94
# Wall time: 9.07 s
# Optimal
# -> Temps : 9.187997579574585s
# N° échantillon : 2 | Nombre de noeuds : 95
# Wall time: 5.17 s
# Optimal
# -> Temps : 5.274127960205078s
# N° échantillon : 2 | Nombre de noeuds : 96
# Wall time: 10.1 s
# Optimal
# -> Temps : 10.172067165374756s
# N° échantillon : 2 | Nombre de noeuds : 97
# Wall time: 31.8 s
# Optimal
# -> Temps : 31.925649166107178s
# N° échantillon : 2 | Nombre de noeuds : 98
# Wall time: 26.8 s
# Optimal
# -> Temps : 26.938733339309692s
# N° échantillon : 3 | Nombre de noeuds : 40
# Wall time: 591 ms
# Optimal
# -> Temps : 0.6096441745758057s
# N° échantillon : 3 | Nombre de noeuds : 41
# Wall time: 475 ms
# Optimal
# -> Temps : 0.5002853870391846s
# N° échantillon : 3 | Nombre de noeuds : 42
# Wall time: 1.47 s
# Optimal
# -> Temps : 1.496387243270874s
# N° échantillon : 3 | Nombre de noeuds : 43
# Wall time: 1.27 s
# Optimal
# -> Temps : 1.297389268875122s
# N° échantillon : 3 | Nombre de noeuds : 44
# Wall time: 2.02 s
# Optimal
# -> Temps : 2.0571141242980957s
# N° échantillon : 3 | Nombre de noeuds : 45
# Wall time: 945 ms
# Optimal
# -> Temps : 0.9762344360351562s
# N° échantillon : 3 | Nombre de noeuds : 46
# Wall time: 1.35 s
# Optimal
# -> Temps : 1.382897138595581s
# N° échantillon : 3 | Nombre de noeuds : 47
# Wall time: 1.18 s
# Optimal
# -> Temps : 1.2057826519012451s
# N° échantillon : 3 | Nombre de noeuds : 48
# Wall time: 7.84 s
# Optimal
# -> Temps : 7.871010780334473s
# N° échantillon : 3 | Nombre de noeuds : 49
# Wall time: 3.13 s
# Optimal
# -> Temps : 3.1578779220581055s
# N° échantillon : 3 | Nombre de noeuds : 50
# Wall time: 520 ms
# Optimal
# -> Temps : 0.5511252880096436s
# N° échantillon : 3 | Nombre de noeuds : 51
# Wall time: 2.77 s
# Optimal
# -> Temps : 2.800722122192383s
# N° échantillon : 3 | Nombre de noeuds : 52
# Wall time: 2.96 s
# Optimal
# -> Temps : 3.0007097721099854s
# N° échantillon : 3 | Nombre de noeuds : 53
# Wall time: 2.3 s
# Optimal
# -> Temps : 2.3307087421417236s
# N° échantillon : 3 | Nombre de noeuds : 54
# Wall time: 1.12 s
# Optimal
# -> Temps : 1.1542882919311523s
# N° échantillon : 3 | Nombre de noeuds : 55
# Wall time: 6.16 s
# Optimal
# -> Temps : 6.199490308761597s
# N° échantillon : 3 | Nombre de noeuds : 56
# Wall time: 1.89 s
# Optimal
# -> Temps : 1.9290833473205566s
# N° échantillon : 3 | Nombre de noeuds : 57
# Wall time: 1.16 s
# Optimal
# -> Temps : 1.211273431777954s
# N° échantillon : 3 | Nombre de noeuds : 58
# Wall time: 1.3 s
# Optimal
# -> Temps : 1.343139886856079s
# N° échantillon : 3 | Nombre de noeuds : 59
# Wall time: 1.69 s
# Optimal
# -> Temps : 1.731459379196167s
# N° échantillon : 3 | Nombre de noeuds : 60
# Wall time: 1.65 s
# Optimal
# -> Temps : 1.6968863010406494s
# N° échantillon : 3 | Nombre de noeuds : 61
# Wall time: 3.61 s
# Optimal
# -> Temps : 3.661560297012329s
# N° échantillon : 3 | Nombre de noeuds : 62
# Wall time: 982 ms
# Optimal
# -> Temps : 1.0276603698730469s
# N° échantillon : 3 | Nombre de noeuds : 63
# Wall time: 1.14 s
# Optimal
# -> Temps : 1.1928846836090088s
# N° échantillon : 3 | Nombre de noeuds : 64
# Wall time: 3.99 s
# Optimal
# -> Temps : 4.0394721031188965s
# N° échantillon : 3 | Nombre de noeuds : 65
# Wall time: 9.88 s
# Optimal
# -> Temps : 9.93877649307251s
# N° échantillon : 3 | Nombre de noeuds : 66
# Wall time: 4.53 s
# Optimal
# -> Temps : 4.579356670379639s
# N° échantillon : 3 | Nombre de noeuds : 67
# Wall time: 1.36 s
# Optimal
# -> Temps : 1.4153110980987549s
# N° échantillon : 3 | Nombre de noeuds : 68
# Wall time: 1.92 s
# Optimal
# -> Temps : 1.9780113697052002s
# N° échantillon : 3 | Nombre de noeuds : 69
# Wall time: 3.1 s
# Optimal
# -> Temps : 3.154240369796753s
# N° échantillon : 3 | Nombre de noeuds : 70
# Wall time: 31.6 s
# Optimal
# -> Temps : 31.6313579082489s
# N° échantillon : 3 | Nombre de noeuds : 71
# Wall time: 13.4 s
# Optimal
# -> Temps : 13.494730949401855s
# N° échantillon : 3 | Nombre de noeuds : 72
# Wall time: 6.52 s
# Optimal
# -> Temps : 6.580794334411621s
# N° échantillon : 3 | Nombre de noeuds : 73
# Wall time: 7.84 s
# Optimal
# -> Temps : 7.907972097396851s
# N° échantillon : 3 | Nombre de noeuds : 74
# Wall time: 1min 3s
# Optimal
# -> Temps : 63.52484607696533s
# N° échantillon : 3 | Nombre de noeuds : 75
# Wall time: 3.08 s
# Optimal
# -> Temps : 3.1509182453155518s
# N° échantillon : 3 | Nombre de noeuds : 76
# Wall time: 10.2 s
# Optimal
# -> Temps : 10.278146743774414s
# N° échantillon : 3 | Nombre de noeuds : 77
# Wall time: 6.1 s
# Optimal
# -> Temps : 6.1736531257629395s
# N° échantillon : 3 | Nombre de noeuds : 78
# Wall time: 2 s
# Optimal
# -> Temps : 2.069843053817749s
# N° échantillon : 3 | Nombre de noeuds : 79
# Wall time: 5.27 s
# Optimal
# -> Temps : 5.352485656738281s
# N° échantillon : 3 | Nombre de noeuds : 80
# Wall time: 2.33 s
# Optimal
# -> Temps : 2.4369070529937744s
# N° échantillon : 3 | Nombre de noeuds : 81
# Wall time: 28.8 s
# Optimal
# -> Temps : 28.93122625350952s
# N° échantillon : 3 | Nombre de noeuds : 82
# Wall time: 56.4 s
# Optimal
# -> Temps : 56.5310263633728s
# N° échantillon : 3 | Nombre de noeuds : 83
# Wall time: 5.2 s
# Optimal
# -> Temps : 5.283689022064209s
# N° échantillon : 3 | Nombre de noeuds : 84
# Wall time: 2min 38s
# Optimal
# -> Temps : 158.56031823158264s
# N° échantillon : 3 | Nombre de noeuds : 85
# Wall time: 36.7 s
# Optimal
# -> Temps : 36.76068305969238s
# N° échantillon : 3 | Nombre de noeuds : 86
# Wall time: 5.26 s
# Optimal
# -> Temps : 5.353713035583496s
# N° échantillon : 3 | Nombre de noeuds : 87
# Wall time: 3.71 s
# Optimal
# -> Temps : 3.8100011348724365s
# N° échantillon : 3 | Nombre de noeuds : 88
# Wall time: 35.1 s
# Optimal
# -> Temps : 35.23745894432068s
# N° échantillon : 3 | Nombre de noeuds : 89
# Wall time: 9.8 s
# Optimal
# -> Temps : 9.89359998703003s
# N° échantillon : 3 | Nombre de noeuds : 90
# Wall time: 31.8 s
# Optimal
# -> Temps : 31.89853835105896s
# N° échantillon : 3 | Nombre de noeuds : 91
# Wall time: 7.24 s
# Optimal
# -> Temps : 7.349920988082886s
# N° échantillon : 3 | Nombre de noeuds : 92
# Wall time: 33.7 s
# Optimal
# -> Temps : 33.84618330001831s
# N° échantillon : 3 | Nombre de noeuds : 93
# Wall time: 10.2 s
# Optimal
# -> Temps : 10.269086122512817s
# N° échantillon : 3 | Nombre de noeuds : 94
# Wall time: 6 s
# Optimal
# -> Temps : 6.108875274658203s
# N° échantillon : 3 | Nombre de noeuds : 95
# Wall time: 10.3 s
# Optimal
# -> Temps : 10.380210876464844s
# N° échantillon : 3 | Nombre de noeuds : 96
# Wall time: 21.5 s
# Optimal
# -> Temps : 21.579004764556885s
# N° échantillon : 3 | Nombre de noeuds : 97
# Wall time: 34.4 s
# Optimal
# -> Temps : 34.5315215587616s
# N° échantillon : 3 | Nombre de noeuds : 98
# Wall time: 25.5 s
# Optimal
# -> Temps : 25.631613731384277s
# N° échantillon : 3 | Nombre de noeuds : 99
# Wall time: 11.3 s
# Optimal
# -> Temps : 11.438284397125244s
# N° échantillon : 3 | Nombre de noeuds : 100
# Wall time: 20 s
# Optimal
# -> Temps : 20.1502366065979s
# N° échantillon : 3 | Nombre de noeuds : 101
# Wall time: 8.98 s
# Optimal
# -> Temps : 9.107654809951782s
# N° échantillon : 3 | Nombre de noeuds : 102
# Wall time: 2min 49s
# Optimal
# -> Temps : 170.00972962379456s
# N° échantillon : 3 | Nombre de noeuds : 103
# Wall time: 8.13 s
# Optimal
# -> Temps : 8.261529684066772s
# N° échantillon : 3 | Nombre de noeuds : 104
# Wall time: 11.4 s
# Optimal
# -> Temps : 11.568579196929932s
# N° échantillon : 3 | Nombre de noeuds : 105
# Wall time: 11.2 s
# Optimal
# -> Temps : 11.35845947265625s
# N° échantillon : 3 | Nombre de noeuds : 106
# Wall time: 2min 13s
# Optimal
# -> Temps : 134.00121068954468s
# N° échantillon : 3 | Nombre de noeuds : 107
# Wall time: 18 s
# Optimal
# -> Temps : 18.136895418167114s
# N° échantillon : 3 | Nombre de noeuds : 108
# Wall time: 42 s
# Optimal
# -> Temps : 42.190147399902344s
# N° échantillon : 3 | Nombre de noeuds : 109
# Wall time: 25.4 s
# Optimal
# -> Temps : 25.56515645980835s
# N° échantillon : 3 | Nombre de noeuds : 110
# Wall time: 1min 23s
# Optimal
# -> Temps : 83.98674607276917s
# N° échantillon : 3 | Nombre de noeuds : 111
# Wall time: 11.6 s
# Optimal
# -> Temps : 11.761175632476807s
# N° échantillon : 3 | Nombre de noeuds : 112
# Wall time: 9.65 s
# Optimal
# -> Temps : 9.835630178451538s
# N° échantillon : 3 | Nombre de noeuds : 113
# Wall time: 18.3 s
# Optimal
# -> Temps : 18.500744581222534s
# N° échantillon : 3 | Nombre de noeuds : 114
# Wall time: 24 s
# Optimal
# -> Temps : 24.132919311523438s
# N° échantillon : 3 | Nombre de noeuds : 115
# Wall time: 4.84 s
# Optimal
# -> Temps : 4.917335033416748s
# N° échantillon : 9 | Nombre de noeuds : 79
# Wall time: 15.2 s
# Optimal
# -> Temps : 15.292031049728394s
# N° échantillon : 9 | Nombre de noeuds : 80
# Wall time: 26.6 s
# Optimal
# -> Temps : 26.635607481002808s
# N° échantillon : 9 | Nombre de noeuds : 81
# Wall time: 2.32 s
# Optimal
# -> Temps : 2.4279279708862305s
# N° échantillon : 9 | Nombre de noeuds : 82
# Wall time: 16.8 s
# Optimal
# -> Temps : 16.87059235572815s
# N° échantillon : 9 | Nombre de noeuds : 83
# Wall time: 18.8 s
# Optimal
# -> Temps : 18.894676208496094s
# N° échantillon : 9 | Nombre de noeuds : 84
# Wall time: 2min 8s
# Optimal
# -> Temps : 128.5215883255005s
# N° échantillon : 9 | Nombre de noeuds : 85
# Wall time: 37.6 s
# Optimal
# -> Temps : 37.742016553878784s
# N° échantillon : 9 | Nombre de noeuds : 86
# Wall time: 8.35 s
# Optimal
# -> Temps : 8.481292009353638s
# N° échantillon : 9 | Nombre de noeuds : 87
# Wall time: 8.17 s
# Optimal
# -> Temps : 8.270930290222168s
# N° échantillon : 9 | Nombre de noeuds : 88
# Wall time: 24 s
# Optimal
# -> Temps : 24.11223840713501s
# N° échantillon : 9 | Nombre de noeuds : 89
# Wall time: 7.39 s
# Optimal
# -> Temps : 7.488620042800903s
# N° échantillon : 9 | Nombre de noeuds : 90
# Wall time: 18.7 s
# Optimal
# -> Temps : 18.888922452926636s
# N° échantillon : 9 | Nombre de noeuds : 91
# Wall time: 7.36 s
# Optimal
# -> Temps : 7.466545581817627s
# N° échantillon : 9 | Nombre de noeuds : 92
# Wall time: 13.9 s
# Optimal
# -> Temps : 13.961587190628052s
# N° échantillon : 9 | Nombre de noeuds : 93
# Wall time: 53.3 s
# Optimal
# -> Temps : 53.43832230567932s
# N° échantillon : 9 | Nombre de noeuds : 94
# Wall time: 9.43 s
# Optimal
# -> Temps : 9.569257020950317s
# N° échantillon : 9 | Nombre de noeuds : 95

# %% [markdown]
# ### >> Timing ILP-DFJ

# %%
isDfjDying = False
dfjResults = np.zeros(nSamples*(nNodes-2)).reshape(nSamples, nNodes-2)+1000

for idx in range(nSamples):
    for n in range(3,nNodes+1):
        
        if not isDfjDying:
            
            print("N° échantillon : {} | Nombre de noeuds : {}".format(idx,n))
            
            costs = np.genfromtxt('./matrices/{}-{}-MTZvsDFJ.csv'.format(idx,n), delimiter=';')
            #costs = np.array(costs, dtype=float)
            #costs = np.nan_to_num(costs, nan=np.inf)

            nodes = [i for i in range(n)]
            maxi = np.inf

            start = time.time()
            solveILP_T(nodes, costs, maxi)
            end = time.time()
            
            if(end-start > time_limit and previous_time>time_limit):
                dfjResults[idx, n-3] = end-start
                isDfjDying = True
            else:
                dfjResults[idx, n-3] = end-start
            print("-> Temps : {}s".format(end-start))
            
    isDfjDying = False
    
np.savetxt("./results/ILP-DFJ-{}-{}-DUEL.csv".format(nSamples,nNodes), dfjResults, delimiter=";")
